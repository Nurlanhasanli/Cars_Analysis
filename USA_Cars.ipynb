# %%
import pandas as pd

# %%
cars2=pd.read_excel ('cars.xlsx')

# %%
df=cars2.copy()

# %%
cars2.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %% [markdown]
# # 1.Question#

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer()
imputer=imputer.fit(df[['hwy']])
df['hwy'] = imputer.transform(df[['hwy']]).ravel()

# %%
df.isnull().sum()
# Out:
# manufacturer    0
# model           0
# displ           5
# year            0
# cyl             0
# trans           0
# drv             0
# cty             4
# hwy             0
# fl              0
# class           0
# dtype: int64

# %% [markdown]
# # 2.Question

# %%
df[['displ', 'cty']] = df [['displ', 'cty']].fillna(method='backfill')

# %%
df.isnull().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# class           0
# dtype: int64

# %% [markdown]
# # 3.Question

# %%
cars2.corr()
# Out:
#           displ      year       cyl       cty       hwy
# displ  1.000000  0.128547  0.931744 -0.812594 -0.769741
# year   0.128547  1.000000  0.122245 -0.039814 -0.014702
# cyl    0.931744  0.122245  1.000000 -0.804726 -0.763860
# cty   -0.812594 -0.039814 -0.804726  1.000000  0.957549
# hwy   -0.769741 -0.014702 -0.763860  0.957549  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sns.PairGrid(cars2)

# %%
g = sns.PairGrid(cars2)
g.map(plt.scatter)

# %%
g = sns.PairGrid(cars2)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\HP\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\contour.py:1520: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\contour.py:1521: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in less
#   under = np.nonzero(lev < self.zmin)[0]
# C:\Users\HP\Anaconda3\lib\site-packages\matplotlib\contour.py:1171: RuntimeWarning: invalid value encountered in greater
#   over = np.nonzero(lev > self.zmax)[0]
# ...

# %% [markdown]
# # 4.Question
# Show relationship between highway and city miles per gallon.
# a. Use scatter in matplotlib.
# b. Interpret how are variables correlated according to scatter.

# %%
plt.scatter(cars2 ['hwy'],cars2 ["cty"], label="some dots",color = 'red')
plt.legend()

# %% [markdown]
# # 5.Question

# %%
sns.pairplot(cars2,hue='drv',palette='rainbow')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\HP\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# # 6.Question

# %%
sns.countplot(x='class',data=cars2)

# %% [markdown]
# # 7.Question
# Display number of cylinders for each drive train in bar chart.
# a. Which drive train is the most frequent?

# %%
cars2.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv   cty   hwy fl    class
# 0         audi    a4    1.8  1999    4    auto(l5)   f  18.0  29.0  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f  21.0  29.0  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f  20.0  31.0  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f  21.0  30.0  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f  16.0  26.0  p  compact

# %%
sns.barplot(cars2["cyl"], cars2["drv"])

# %% [markdown]
# # 8.Question
# Visualize engine displacement by each class, using boxplot.

# %%
sns.boxplot(x="class", y="displ", data=cars2,palette='rainbow')

# %% [markdown]
# # 9. Question
# Do the same thing in violinplot

# %%
sns.violinplot(x="class", y="displ", data=cars2,palette='rainbow')
